# %%
import numpy as np
from ccdproc import wcs_project
from astropy import units as u
from astropy.coordinates import SkyCoord
from matplotlib import pyplot as plt
from astropy.wcs import WCS
from astropy.nddata import Cutout2D
from astropy.io import fits
from astropy import wcs

# %%
cutouts = np.load('VHzQ_LoTSSDR2_cutouts.npz')

print(cutouts)

# %%
np.savez_compressed('VHzQ_LoTSSDR2_cutouts.npz', array1='array1', array2='array2')
b = np.load('VHzQ_LoTSSDR2_cutouts.npz')

# %%
print(b['array1'])
# Out:
# array1

# %%
images = np.load('VHzQ_LoTSSDR2_cutouts.npz')
images.keys()
print(images)
#images = images.f.arr_0

# %%
img_array = np.load('VHzQ_LoTSSDR2_cutouts.npz')

plt.imshow(img_array, cmap='gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-3fe389e378fd> in <module>
#       3 img_array = np.load('VHzQ_LoTSSDR2_cutouts.npz')
#       4
# ----> 5 plt.imshow(img_array, cmap='gray')
#       6 plt.show()
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2681         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2682         resample=resample, url=url, **({"data": data} if data is not
# -> 2683         None else {}), **kwargs)
#    2684     sci(__ret)
#    2685     return __ret
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
# ...

# %%
img_array=np.load('VHzQ_LoTSSDR2_cutouts.npz')

for idx, el in enumerate(img_array):
    plt.imshow(img_array[idx], cmap='gray')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-be8bb35aab4d> in <module>
#       2
#       3 for idx, el in enumerate(img_array):
# ----> 4     plt.imshow(img_array[idx], cmap='gray')
#       5     plt.show()
#
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in __getitem__(self, key)
#     260                 return self.zip.read(key)
#     261         else:
# --> 262             raise KeyError("%s is not a file in the archive" % key)
#     263
#     264
#
# KeyError: '0 is not a file in the archive'

# %%
img_array=np.load('VHzQ_LoTSSDR2_cutouts.npz')
print(img_array)

# %%
img_array.files
# Out:
# ['data']

# %%
img_array['data'][0]
# Out:
# array([[-1.20896449e-04, -1.16164034e-04, -4.69705077e-05, ...,
#         -9.27037967e-05, -6.12968798e-05, -5.18209123e-05],
#        [-6.45010743e-05, -7.40037303e-05, -4.26009650e-05, ...,
#         -4.48351849e-05, -2.49005427e-05, -1.53838916e-05],
#        [-4.53130061e-05, -7.85639291e-05, -7.48556909e-05, ...,
#         -3.19181939e-05,  1.83687009e-07,  3.13508786e-05],
#        ...,
#        [ 2.14376984e-04,  2.06766154e-04,  1.88249297e-04, ...,
#          4.21022530e-05,  1.25897231e-05,  3.31789562e-05],
#        [ 1.18664037e-04,  1.04108091e-04,  8.61085315e-05, ...,
#          7.36230601e-06, -3.79871110e-05, -4.23993869e-05],
#        [-3.27345039e-05, -2.43408096e-05, -4.80575695e-06, ...,
#         -3.84082420e-05, -8.99314829e-05, -1.13007850e-04]])

# %%
plt.imshow(img_array['data'][1])

# %%
c = SkyCoord(ra=0.34011348*u.degree, dec=26.83588138*u.degree, frame='icrs')
print(c.to_string('hmsdms'))
loc = c.to_string('hmsdms').find('+')

print(c.to_string('hmsdms')[0:2]+':'+c.to_string('hmsdms')[3:5]+':'+c.to_string('hmsdms')[6:11]+' '+ c.to_string('hmsdms')[loc:loc+3]+':'+ c.to_string('hmsdms')[loc+4:loc+6]+':'+ c.to_string('hmsdms')[loc+7:loc+12])
# Out:
# 00h01m21.6272s +26d50m09.173s
# 00:01:21.62 +26:50:09.17

# %%
image_path ='/Users/anniekgloudemans/Documents/AA_PhD/Data/WISE/WISE_Files_idrop/2487p424_ac51-w4-int-3_ra248.911371_dec42.046892_asec100.000.fits'

ra1 = 248.911371
dec1 = 42.046892
c= SkyCoord(ra=ra1*u.degree, dec=dec1*u.degree, frame='icrs')
image = fits.open(image_path)
# print(image.info())
# print(WCS(image[0].header))

# print(WCS(image_path))

w = wcs.WCS(image[0].header)

plt.imshow(image[0].data)

# %%
from astropy.nddata import CCDData
image_path ='/Users/anniekgloudemans/Documents/AA_PhD/Data/high_z_lofar_sources/color_cut/cutouts/ukidss/hectomap/idrop/001_141756.0+420421_J.fits'#/Users/anniekgloudemans/Documents/AA_PhD/Data/high_z_lofar_sources/color_cut/cutouts/unwise_cutouts/hectomap/idrop/W1 copy/cutout_fits?version=neo1&ra=214.4833368451023&dec=42.07243282728451&size=200&bands=1&file_img_m.tar'#'/Users/anniekgloudemans/Documents/AA_PhD/Data/high_z_lofar_sources/color_cut/cutouts/unwise_cutouts/hectomap/idrop/W1/cutout_fits?version=neo1&ra=214.4833368451023&dec=42.07243282728451&size=200&bands=1&file_img_m=on'#'/Users/anniekgloudemans/Documents/AA_PhD/Data/high_z_lofar_sources/color_cut/cutouts/unwise_cutouts/hectomap/zdrop/W1/cutout_fits?version=neo1&ra=212.17914531277987&dec=44.034101704729004&size=200&bands=1&file_img_m=on'


img_array=np.load('/Users/anniekgloudemans/Documents/AA_PhD/Data/high_z_lofar_sources/color_cut/lotss_cutouts/VHzQ_LoTSSDR2_cutouts_idrop.npz')
wcs_array=np.load('/Users/anniekgloudemans/Documents/AA_PhD/Data/high_z_lofar_sources/color_cut/lotss_cutouts/VHzQ_LoTSSDR2_cutouts_idrop_wcs.npz')

print(wcs_array.files)
lofar_data = img_array['data'][0]
lofar_wcs = wcs_array['data'][0]

print(list(img_array['data']))
# #plt.imshow(img_array['data'][0])
# #wcs = WCS(lofar_data)
# ra = 214.48333685
# dec = 42.07243283
# image_size_arcsec = 50
# c = SkyCoord(ra, dec, frame='fk5', unit='deg')

# img = CCDData.read(image_path)
# new_image = wcs_project(img, target_wcs)

# lae1_radio = Cutout2D(data=lofar_data, 
#                       position=c,
#                       size=image_size_arcsec*u.arcsec,
#                       wcs = lofar_wcs)


# plt.imshow(lae1_radio.data, cmap='gray')
# Out:
# ['data']
# [array([[-1.39384271e-04, -9.22288766e-05, -2.06391921e-05, ...,
#          4.50110853e-05,  6.25977744e-06, -4.18906337e-05],
#        [-1.76798804e-04, -1.28743956e-04, -4.00270135e-05, ...,
#          5.71060021e-05,  6.05387658e-05,  2.80893019e-05],
#        [-1.42763645e-04, -1.04940480e-04, -4.50640045e-05, ...,
#         -1.28044910e-05,  1.23241429e-05,  3.22735215e-05],
#        ...,
#        [-8.36874390e-05, -5.87088431e-05, -2.04172062e-05, ...,
#         -6.41003125e-06, -3.33090396e-05, -9.28691735e-05],
#        [-7.00933990e-05, -6.74496405e-05, -4.03218986e-05, ...,
#         -4.35757970e-05, -3.56761230e-05, -5.21745247e-05],
#        [-4.71970249e-05, -7.05624103e-05, -3.85804367e-05, ...,
#         -7.61594339e-05, -3.65673057e-05, -2.39141843e-05]]), array([[ 1.26679297e-04,  1.17841212e-04,  9.93141078e-05, ...,
#         -7.51991407e-05, -1.08268607e-04, -1.00673852e-04],
#        [ 1.39273124e-05,  4.17409100e-05,  5.39779324e-05, ...,
# ...

# %%
c = SkyCoord(131.122687, 0.899318, frame='fk5', unit='deg')

image = fits.open('cutouts/hsc_cutouts/gama/idrop/g_filter_idrop_hsc_W03_lofar_09_goldrush/cutout?ra=131.1226869571045&dec=0.899317932338034&sw=10asec&sh=10asec&type=coadd&image=on&filter=HSC-G&tract=&rerun=pdr2_wide')

optical_wcs = WCS(image[1].header)
        
lofar_mosaic = fits.open('/Users/anniekgloudemans/Documents/AA_PhD/Data/LOFAR_GAMA/G09-mosaic.fits')
lofar_wcs = WCS(lofar_mosaic[0].header, naxis=2)

lofar_data = np.squeeze(lofar_mosaic[0].data)
#lofar_image_data = wcs_project(lofar_ccd, optical_wcs)


lae1_radio = Cutout2D(data=lofar_data,#lofar_image_data,#lofar_data,
                   position=c,
                   size=30*u.arcsec,
                   wcs=lofar_wcs)#optical_wcs)#lofar_wcs)

proj_image_lofar = CCDData(lae1_radio.data, unit="adu", wcs=lofar_wcs)#, unit="adu")
lofar_image_data = wcs_project(proj_image_lofar, optical_wcs)

f = plt.figure(figsize=(10,10))
Ax = f.add_subplot(2, 5, 1, projection=optical_wcs) #Ax = f.add_subplot(rows_images, columns_images, i+1, projection=lae1_radio.wcs)

# Ax.imshow(lofar_image_data.data, cmap='gray', origin='lower')#, vmin=-1*radio_rms, vmax=5*radio_rms)
# Ax.contour(lofar_image_data.data)
#Ax.scatter(ra_opt_sort[i], dec_opt_sort[i], transform=Ax.get_transform('fk5'), s=700, marker='+', color='white')#, facecolor='none')
#Ax.imshow(lae1_radio.data)
Ax.imshow(lofar_image_data)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/image.py:397: UserWarning: Warning: converting a masked element to nan.
#   dv = (np.float64(self.norm.vmax) -
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/image.py:398: UserWarning: Warning: converting a masked element to nan.
#   np.float64(self.norm.vmin))
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/image.py:405: UserWarning: Warning: converting a masked element to nan.
#   a_min = np.float64(newmin)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/image.py:410: UserWarning: Warning: converting a masked element to nan.
#   a_max = np.float64(newmax)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py:933: UserWarning: Warning: converting a masked element to nan.
#   dtype = np.min_scalar_type(value)
# /opt/anaconda3/lib/python3.7/site-packages/numpy/ma/core.py:713: UserWarning: Warning: converting a masked element to nan.
#   data = np.array(a, copy=False, subok=subok)
# ...

# %%
test = 'bladjsklfsjld'
print(test.find('adj'))
# Out:
# 2

# %%
optical_wcs = WCS(image[0].header, naxis=2)

lae1_optical = Cutout2D(data=image[0].data,
                  position=c,
                  size=60*u.arcsec,
                  wcs=optical_wcs)

#optical_rms = mad_std(lae1_optical.data)

plt.imshow(lae1_optical.data)#,cmap=color_maps[j],origin="lower", vmin=-1*optical_rms, vmax=3*optical_rms) #-1 - +

# %%
from astropy.io import fits
from astropy import wcs

image_path ='/Users/anniekgloudemans/Documents/AA_PhD/Data/high_z_lofar_sources/color_cut/cutouts/ukidss/hectomap/idrop/001_141756.0+420421_J.fits'#/Users/anniekgloudemans/Documents/AA_PhD/Data/high_z_lofar_sources/color_cut/cutouts/unwise_cutouts/hectomap/idrop/W1 copy/cutout_fits?version=neo1&ra=214.4833368451023&dec=42.07243282728451&size=200&bands=1&file_img_m.tar'#'/Users/anniekgloudemans/Documents/AA_PhD/Data/high_z_lofar_sources/color_cut/cutouts/unwise_cutouts/hectomap/idrop/W1/cutout_fits?version=neo1&ra=214.4833368451023&dec=42.07243282728451&size=200&bands=1&file_img_m=on'#'/Users/anniekgloudemans/Documents/AA_PhD/Data/high_z_lofar_sources/color_cut/cutouts/unwise_cutouts/hectomap/zdrop/W1/cutout_fits?version=neo1&ra=212.17914531277987&dec=44.034101704729004&size=200&bands=1&file_img_m=on'

ra1 = 212.17914531277987
dec1 = 44.034101704729004
c= SkyCoord(ra=ra1*u.degree, dec=dec1*u.degree, frame='icrs')
image = fits.open(image_path)
print(image.info())
print(WCS(image[1].header))

print(WCS(image_path))

w = wcs.WCS(image[1].header)

plt.imshow(image[1].data)
# Out:
# Filename: /Users/anniekgloudemans/Documents/AA_PhD/Data/high_z_lofar_sources/color_cut/cutouts/ukidss/hectomap/idrop/001_141756.0+420421_J.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     216   ()
#   1                1 ImageHDU       104   (300, 290)   int32 (rescales to float64)
# None
# WCS Transformation
#
# This transformation has 2 pixel and 2 world dimensions
#
# Array shape (Numpy order): (290, 300)
#
# Pixel Dim  Data size  Bounds
#         0        300  None
#         1        290  None
#
# World Dim  Physical Type  Units
#         0  pos.eq.ra      deg
#         1  pos.eq.dec     deg
#
# Correlation between pixel and world axes:
#
#            Pixel Dim
# World Dim    0    1
#         0  yes  yes
#         1  yes  yes
# WCS Transformation
#
# This transformation has 2 pixel and 2 world dimensions
#
# Array shape (Numpy order): None
#
# Pixel Dim  Data size  Bounds
#         0       None  None
# ...

# %%
image = ''

optical_wcs = WCS(image[0].header, naxis=2)

lae1_optical = Cutout2D(data=image[0].data,
                  position=c,
                  size=60*u.arcsec,
                  wcs=optical_wcs)

#optical_rms = mad_std(lae1_optical.data)

plt.imshow(lae1_optical.data)

# %% [markdown]
# ## LOFAR numpy array

# %%
part1 = np.load('/Users/anniekgloudemans/Documents/AA_PhD/Data/high_z_lofar_sources/color_cut/cutouts/lofar/hectomap/banados/idrop/hectomap_3asec_banados_idrop_cutouts_part1.npz')['data']
part2 = np.load('/Users/anniekgloudemans/Documents/AA_PhD/Data/high_z_lofar_sources/color_cut/cutouts/lofar/hectomap/banados/idrop/hectomap_3asec_banados_idrop_cutouts_part2.npz')['data']
part3 = np.load('/Users/anniekgloudemans/Documents/AA_PhD/Data/high_z_lofar_sources/color_cut/cutouts/lofar/hectomap/banados/idrop/hectomap_3asec_banados_idrop_cutouts_part3.npz')['data']

part1_wcs = np.load('/Users/anniekgloudemans/Documents/AA_PhD/Data/high_z_lofar_sources/color_cut/cutouts/lofar/hectomap/banados/idrop/hectomap_3asec_banados_idrop_cutouts_wcs_part1.npz')['data']
part2_wcs = np.load('/Users/anniekgloudemans/Documents/AA_PhD/Data/high_z_lofar_sources/color_cut/cutouts/lofar/hectomap/banados/idrop/hectomap_3asec_banados_idrop_cutouts_wcs_part2.npz')['data']
part3_wcs = np.load('/Users/anniekgloudemans/Documents/AA_PhD/Data/high_z_lofar_sources/color_cut/cutouts/lofar/hectomap/banados/idrop/hectomap_3asec_banados_idrop_cutouts_wcs_part3.npz')['data']



#print(part1)

x = np.concatenate((part1, part2), axis=0)
print(len(part1))
print(len(x))
y = np.concatenate((x, part3), axis=0)
print(len(y))

x_wcs = np.concatenate((part1_wcs, part2_wcs), axis=0)
y_wcs = np.concatenate((x_wcs, part3_wcs), axis=0)
print(len(y_wcs))
np.savez('/Users/anniekgloudemans/Documents/AA_PhD/Data/high_z_lofar_sources/color_cut/cutouts/lofar/hectomap/banados/idrop/hectomap_3asec_banados_idrop_cutouts.npz', data=y)
np.savez('/Users/anniekgloudemans/Documents/AA_PhD/Data/high_z_lofar_sources/color_cut/cutouts/lofar/hectomap/banados/idrop/hectomap_3asec_banados_idrop_cutouts_wcs.npz', data=y_wcs)
# Out:
# 399
# 799
# 1139
# 1139

# %%
x = np.concatenate(np.array([[1,2], [3,4], [5,6]]), np.array([[1,2], [3,4], [5,6]]))
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-0a2f48650f22> in <module>
# ----> 1 x = np.concatenate(np.array([[1,2], [3,4], [5,6]]), np.array([[1,2], [3,4], [5,6]]))
#       2 print(x)
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
# write to file
ascii.write([np.round(opt_matched_catalog['ra'][drop_matched_bool],6), np.round(opt_matched_catalog['dec'][drop_matched_bool],6)], 'coord_files/coord_{0}_{5}_{1}_{2}_{3}asec_{4}_lofar.dat'.format(field_name, cat_hsc_name, cat_lofar_name, asec, drop, color_cut ), names=['ra', 'dec'], overwrite=True)

# %%
fits_name = '/Users/anniekgloudemans/Documents/AA_PhD/Data/high_z_lofar_sources/color_cut/cutouts/legacy/known_quasars_lofar/w2_filter/fits-cutout?ra=356.1395833&dec=16.8879111&layer=dr8&pixscale=0.27&bands=w2'
image = fits.open(fits_name)
c= SkyCoord(356.1395833,16.8879111, frame='fk5', unit='deg')

optical_wcs = WCS(image[0].header, naxis=2)

lae1_optical = Cutout2D(data=image[0].data,
                  position=c,
                  size=20*u.arcsec,
                  wcs=optical_wcs)

#optical_rms = mad_std(lae1_optical.data)

plt.imshow(lae1_optical.data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-c39dc7b2b809> in <module>
#       8                   position=c,
#       9                   size=20*u.arcsec,
# ---> 10                   wcs=optical_wcs)
#      11
#      12 #optical_rms = mad_std(lae1_optical.data)
#
# /opt/anaconda3/lib/python3.7/site-packages/astropy/nddata/utils.py in __init__(self, data, position, size, wcs, mode, fill_value, copy)
#     685         cutout_data, input_position_cutout = extract_array(
#     686             data, tuple(shape), pos_yx, mode=mode, fill_value=fill_value,
# --> 687             return_position=True)
#     688         if copy:
#     689             cutout_data = np.copy(cutout_data)
#
# /opt/anaconda3/lib/python3.7/site-packages/astropy/nddata/utils.py in extract_array(array_large, shape, position, mode, fill_value, return_position)
# ...

# %%
# %matplotlib inline

import numpy
from astropy.table import Table
import requests
from PIL import Image
from io import BytesIO
import pylab

# %%
def getimages(ra,dec,size=240,filters="grizy"):
    
    """Query ps1filenames.py service to get a list of images
    
    ra, dec = position in degrees
    size = image size in pixels (0.25 arcsec/pixel)
    filters = string with filters to include
    Returns a table with the results
    """
    
    service = "https://ps1images.stsci.edu/cgi-bin/ps1filenames.py"
    url = ("{service}?ra={ra}&dec={dec}&size={size}&format=fits"
           "&filters={filters}").format(**locals())
    table = Table.read(url, format='ascii')
    return table


def geturl(ra, dec, size=240, output_size=None, filters="grizy", format="jpg", color=False):
    
    """Get URL for images in the table
    
    ra, dec = position in degrees
    size = extracted image size in pixels (0.25 arcsec/pixel)
    output_size = output (display) image size in pixels (default = size).
                  output_size has no effect for fits format images.
    filters = string with filters to include
    format = data format (options are "jpg", "png" or "fits")
    color = if True, creates a color image (only for jpg or png format).
            Default is return a list of URLs for single-filter grayscale images.
    Returns a string with the URL
    """
    
    if color and format == "fits":
        raise ValueError("color images are available only for jpg or png formats")
    if format not in ("jpg","png","fits"):
        raise ValueError("format must be one of jpg, png, fits")
    table = getimages(ra,dec,size=size,filters=filters)
    url = ("https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?"
           "ra={ra}&dec={dec}&size={size}&format={format}").format(**locals())
    if output_size:
        url = url + "&output_size={}".format(output_size)
    # sort filters from red to blue
    flist = ["yzirg".find(x) for x in table['filter']]
    table = table[numpy.argsort(flist)]
    if color:
        if len(table) > 3:
            # pick 3 filters
            table = table[[0,len(table)//2,len(table)-1]]
        for i, param in enumerate(["red","green","blue"]):
            url = url + "&{}={}".format(param,table['filename'][i])
    else:
        urlbase = url + "&red="
        url = []
        for filename in table['filename']:
            url.append(urlbase+filename)
    print(url)
    return url


def getcolorim(ra, dec, size=240, output_size=None, filters="grizy", format="jpg"):
    
    """Get color image at a sky position
    
    ra, dec = position in degrees
    size = extracted image size in pixels (0.25 arcsec/pixel)
    output_size = output (display) image size in pixels (default = size).
                  output_size has no effect for fits format images.
    filters = string with filters to include
    format = data format (options are "jpg", "png")
    Returns the image
    """
    
    if format not in ("jpg","png"):
        raise ValueError("format must be jpg or png")
    url = geturl(ra,dec,size=size,filters=filters,output_size=output_size,format=format,color=True)
    r = requests.get(url)
    im = Image.open(BytesIO(r.content))
    return im


def getgrayim(ra, dec, size=240, output_size=None, filter="g", format="jpg"):
    
    """Get grayscale image at a sky position
    
    ra, dec = position in degrees
    size = extracted image size in pixels (0.25 arcsec/pixel)
    output_size = output (display) image size in pixels (default = size).
                  output_size has no effect for fits format images.
    filter = string with filter to extract (one of grizy)
    format = data format (options are "jpg", "png")
    Returns the image
    """
    
    if format not in ("jpg","png"):
        raise ValueError("format must be jpg or png")
    if filter not in list("grizy"):
        raise ValueError("filter must be one of grizy")
    url = geturl(ra,dec,size=size,filters=filter,output_size=output_size,format=format)
    r = requests.get(url[0])
    im = Image.open(BytesIO(r.content))
    return im

# %%
from astropy.io import fits
from astropy.visualization import PercentileInterval, AsinhStretch

# Crab Nebula position
ra = 83.633210
dec = 22.014460
size = 1280

# grayscale image
gim = getgrayim(ra,dec,size=size,filter="i")
# color image
cim = getcolorim(ra,dec,size=size,filters="grz")

fitsurl = geturl(ra, dec, size=size, filters="i", format="fits")
fh = fits.open(fitsurl[0])
fim = fh[0].data
# replace NaN values with zero for display
fim[numpy.isnan(fim)] = 0.0
# set contrast to something reasonable
transform = AsinhStretch() + PercentileInterval(99.5)
bfim = transform(fim)

pylab.figure(1,(12,6))
pylab.subplot(121)
pylab.imshow(gim,origin="upper")
pylab.title('Crab Nebula PS1 i (jpeg)')

pylab.subplot(122)
pylab.title('Crab Nebula PS1 i (fits)')
pylab.imshow(bfim,cmap="gray",origin="lower")
# Out:
# ['https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?ra=83.63321&dec=22.01446&size=1280&format=jpg&red=/rings.v3.skycell/1784/059/rings.v3.skycell.1784.059.stk.i.unconv.fits']
# https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?ra=83.63321&dec=22.01446&size=1280&format=jpg&red=/rings.v3.skycell/1784/059/rings.v3.skycell.1784.059.stk.z.unconv.fits&green=/rings.v3.skycell/1784/059/rings.v3.skycell.1784.059.stk.r.unconv.fits&blue=/rings.v3.skycell/1784/059/rings.v3.skycell.1784.059.stk.g.unconv.fits
# ['https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?ra=83.63321&dec=22.01446&size=1280&format=fits&red=/rings.v3.skycell/1784/059/rings.v3.skycell.1784.059.stk.i.unconv.fits']
